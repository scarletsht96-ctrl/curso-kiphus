# %% [markdown]
# <a href="https://colab.research.google.com/github/scarletsht96-ctrl/curso-kiphus/blob/main/Pandas_Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Khipus.ai
# ## Fundamentals of Data Science
# ### Python (NumPy): <span>
# ### Name : (Your name here)
# ### © Copyright Notice 2025, Khipus.ai - All Rights Reserved.</span>
#
# # Assignment 3

# %% [markdown]
# ## Instructions
# 1. Complete each task below by filling in the appropriate code in the provided cells.
# 2. Ensure that your code runs without errors and produces the expected outputs.
# 3. Submit your completed notebook as instructed by your instructor.

# %% [markdown]
# 1. Create a Pandas DataFrame with the following data:
#
# | Name    | Age | Department |
# |---------|-----|------------|
# | Alice   | 24  | HR         |
# | Bob     | 30  | IT         |
# | Charlie | 22  | Marketing  |
#
# Display the DataFrame.
#
# Expected output:
#
#     Name	Age	Department
#
# 0	Alice	24	HR
#
# 1	Bob	30	IT
#
# 2	Charlie	22	Marketing

# %%
import pandas as pd

import pandas as pd

data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Age": [24, 30, 22],
    "Department": ["HR", "IT", "Marketing"]
}

df = pd.DataFrame(data)
df
# Out:
#       Name  Age Department
# 0    Alice   24         HR
# 1      Bob   30         IT
# 2  Charlie   22  Marketing

# %% [markdown]
# 2. Add a new column `Salary` to the DataFrame with the values `[50000, 60000, 45000]`. Display the updated DataFrame.
#
# Expected output
#
# 	Name	Age	Department	Salary
#
# 0	Alice	24	HR	50000
#
# 1	Bob	30	IT	60000
#
# 2	Charlie	22	Marketing	45000

# %%
df["Salary"] = [50000, 60000, 45000]
df
# Out:
#       Name  Age Department  Salary
# 0    Alice   24         HR   50000
# 1      Bob   30         IT   60000
# 2  Charlie   22  Marketing   45000

# %% [markdown]
# 3. Filter the DataFrame to display only the rows where `Age` is greater than 25.
#
# Expected output:
#
# Name	Age	Department	Salary
#
# 1	Bob	30	IT	60000

# %%
df[df["Age"] > 25]
# Out:
#   Name  Age Department  Salary
# 1  Bob   30         IT   60000

# %% [markdown]
# 4. Sort the DataFrame by `Name` in ascending order. Display the sorted DataFrame.
#
# Expected output:
#
# Name	Age	Department	Salary
#
# 0	Alice	24	HR	50000
#
# 1	Bob	30	IT	60000
#
# 2	Charlie	22	Marketing	45000

# %%
df.sort_values(by="Name", ascending=True)
# Out:
#       Name  Age Department  Salary
# 0    Alice   24         HR   50000
# 1      Bob   30         IT   60000
# 2  Charlie   22  Marketing   45000
